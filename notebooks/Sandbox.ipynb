# %%
import pandas as pd

df_instacart_orders = pd.read_csv("/workspace/notebooks/datasets/sprint4/instacart_orders.csv", sep=";")

print(f"cantidad de duplicados: {df_instacart_orders.duplicated(keep='first').sum()}")
print(df_instacart_orders.duplicated())
print("----------------------------------------------------------------------")
# 
df_duplicated = df_instacart_orders[df_instacart_orders.duplicated(keep=False)]
print(df_duplicated.sort_values(by='order_id'))
print(df_duplicated.shape[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 5
#       1 import pandas as pd
#       3 df_instacart_orders = pd.read_csv("/workspace/notebooks/datasets/sprint4/instacart_orders.csv", sep=";")
# ----> 5 print(f"cantidad de duplicados: {df_instacart_orders.duplicated(keep=True).sum()}")
#       6 print(df_instacart_orders.duplicated())
#       7 print("----------------------------------------------------------------------")
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py:6719, in DataFrame.duplicated(self, subset, keep)
#    6709     labels, shape = map(list, zip(*map(f, vals)))
#    6711     ids = get_group_index(
#    6712         labels,
#    6713         # error: Argument 1 to "tuple" has incompatible type "List[_T]";
#    (...)
#    6717         xnull=False,
#    6718     )
# ...
